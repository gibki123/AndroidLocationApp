# %%
import pandas as pd
import numpy as np
from xgboost import XGBClassifier

# %%
# Read Data from php server
myLocationData = pd.read_html('https://serwer1990534.home.pl/LocationData.php')

# %%
# Drop unsignificant data and change column names
location_df = myLocationData[0]
location_df = location_df[220:-1]
location_df = location_df.drop([0,5], axis = 1)
location_df = location_df.rename(columns={1:'place_name',2:'place_types',3:'presence_likelihood',4:"datetime"})

# get only the best likelihoods of certain time
likelihood_maxes = location_df.groupby(['datetime']).presence_likelihood.transform(max)
location_df_max_likelihood = location_df.loc[location_df.presence_likelihood == likelihood_maxes]
location_df_max_likelihood = location_df_max_likelihood.reset_index(drop = True)
location_df_max_likelihood = location_df_max_likelihood.sort_values('datetime', ascending = False)


# Change strring type to datetime (easy getter for cartain datatime types)
location_df_max_likelihood['datetime'] = pd.to_datetime(location_df_max_likelihood['datetime'], format='%m-%d-%Y %H:%M:%S')

# Generate columns for all types
for index, row in location_df_max_likelihood.iterrows():
    string_to_chop = row['place_types'][:-1]
    types = [x.strip() for x in string_to_chop.split(',')]
    for number,location_type in enumerate(types, start=1):
        location_df_max_likelihood.loc[index,'type_' + str(number)] = location_type
        
# Fill all none types with 0
location_df_max_likelihood = location_df_max_likelihood.fillna(0)

# Drop comas place types
# location_df_max_likelihood = location_df_max_likelihood.drop(['place_types'], axis=1)

# %%
# Get all column names
type_columns = location_df_max_likelihood.columns[4:]

# %%
type_columns
# Out:
# Index(['type_1', 'type_2', 'type_3', 'type_4', 'type_5', 'type_6', 'type_7',
#        'type_8', 'type_9', 'type_10', 'type_11', 'type_12'],
#       dtype='object')

# %%
# Find most popular types per last week day and 4 hour for every rows
for index, row in location_df_max_likelihood.iterrows():
    searching = True
    iterator = 0
# Existed places dictionaries
    dictionary_4_hour = {}
    dictionary_1_day = {}
    dictionary_7_days = {}
# Main lopp looking on past 7 days places 
    while searching == True:  
        current_row = location_df_max_likelihood.iloc[index - iterator]        
        for type_name in type_columns:
            place_type = current_row[type_name]
            if place_type != 0 and place_type !="POINT_OF_INTEREST" and place_type !="ESTABLISHMENT":
                if place_type in dictionary_4_hour.keys() and iterator <= 12:
                    dictionary_4_hour[place_type] += 1
                else:
                    dictionary_4_hour[place_type]  = 1
                if place_type in dictionary_1_day.keys() and iterator <= 54:
                    dictionary_1_day[place_type] += 1
                else:
                    dictionary_1_day[place_type] = 1
                if place_type in dictionary_7_days.keys() and iterator <= 378:
                    dictionary_7_days[place_type] += 1
                else:
                    dictionary_7_days[place_type] = 1
        iterator += 1
        if index - iterator < 0 or iterator > 378:
            searching = False
# Search most frequent places in certain datatime frames
    max_4_hour_type = max(dictionary_4_hour, key=dictionary_4_hour.get)
    max_1_day_type = max(dictionary_1_day, key=dictionary_1_day.get)
    max_7_days_type = max(dictionary_7_days, key=dictionary_7_days.get)
# Set most frequent places in certain datatimes
    location_df_max_likelihood.loc[index, 'type_4_hours'] = max_4_hour_type
    location_df_max_likelihood.loc[index, 'type_1_day'] = max_1_day_type
    location_df_max_likelihood.loc[index, 'type_7_days'] = max_7_days_type  
    
    print(index,"row data filled with")

location_df_max_likelihood.to_csv('frequent_locations.csv')
# Out:
# 11330 row data filled with
# 11329 row data filled with
# 11328 row data filled with
# 11327 row data filled with
# 11326 row data filled with
# 11325 row data filled with
# 11324 row data filled with
# 11323 row data filled with
# 11322 row data filled with
# 11321 row data filled with
# 11320 row data filled with
# 11319 row data filled with
# 11318 row data filled with
# 11317 row data filled with
# 11316 row data filled with
# 11315 row data filled with
# 11314 row data filled with
# 11313 row data filled with
# 11312 row data filled with
# 11311 row data filled with
# 11310 row data filled with
# 11309 row data filled with
# 11308 row data filled with
# 11307 row data filled with
# 11306 row data filled with
# 11305 row data filled with
# 11304 row data filled with
# 11303 row data filled with
# 11302 row data filled with
# 11301 row data filled with
# 11300 row data filled with
# 11299 row data filled with
# 11298 row data filled with
# 11297 row data filled with
# 11296 row data filled with
# 11295 row data filled with
# 11294 row data filled with
# 11293 row data filled with
# 11292 row data filled with
# 11291 row data filled with
# 11290 row data filled with
# 11289 row data filled with
# 11288 row data filled with
# 11287 row data filled with
# 11286 row data filled with
# 11285 row data filled with
# 11284 row data filled with
# 11283 row data filled with
# 11282 row data filled with
# 11281 row data filled with
# 11280 row data filled with
# 11279 row data filled with
# 11278 row data filled with
# 11277 row data filled with
# 11276 row data filled with
# 11275 row data filled with
# 11274 row data filled with
# 11273 row data filled with
# 11272 row data filled with
# 11271 row data filled with
# 11270 row data filled with
# 11269 row data filled with
# 11268 row data filled with
# 11267 row data filled with
# 11266 row data filled with
# 11265 row data filled with
# 11264 row data filled with
# 11263 row data filled with
# 11262 row data filled with
# 11261 row data filled with
# 11260 row data filled with
# 11259 row data filled with
# 11258 row data filled with
# 11257 row data filled with
# 11256 row data filled with
# 11255 row data filled with
# 11254 row data filled with
# 11253 row data filled with
# 11252 row data filled with
# 11251 row data filled with
# 11250 row data filled with
# 11249 row data filled with
# 11248 row data filled with
# 11247 row data filled with
# 11246 row data filled with
# 11245 row data filled with
# 11244 row data filled with
# 11243 row data filled with
# 11242 row data filled with
# 11241 row data filled with
# 11240 row data filled with
# 11239 row data filled with
# 11238 row data filled with
# 11237 row data filled with
# 11236 row data filled with
# 11235 row data filled with
# 11234 row data filled with
# 11233 row data filled with
# 11232 row data filled with
# 11231 row data filled with
# 11230 row data filled with
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-b0abbdde7d37> in <module>
#      11         current_row = location_df_max_likelihood.iloc[index - iterator]
#      12         for type_name in type_columns:
# ---> 13             place_type = current_row[type_name]
#      14             if place_type != 0 and place_type !="POINT_OF_INTEREST" and place_type !="ESTABLISHMENT":
#      15                 if place_type in dictionary_4_hour.keys() and iterator <= 12:
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     868     def __getitem__(self, key):
#     869         key = com.apply_if_callable(key, self)
# --> 870         try:
#     871             result = self.index.get_value(self, key)
#     872
#
# KeyboardInterrupt:

# %%
frequent_location_df = pd.read_csv('frequent_locations.csv')

# %%
frequent_location_df = frequent_location_df.drop(['Unnamed: 0'], axis = 1)

# %%
frequent_location_df.datetime = pd.to_datetime(frequent_location_df.datetime, format='%Y-%m-%d %H:%M:%S' )

# %%
days = frequent_location_df['datetime'].dt.weekday
hours = frequent_location_df['datetime'].dt.hour
mins = frequent_location_df['datetime'].dt.minute

# %%
frequent_location_df['weekday'] = days
frequent_location_df['mins'] = mins
frequent_location_df['hours'] = hours

# %%
frequent_location_df.shape[0]
# Out:
# 11331

# %%
frequent_location_df['week_bfr_4_hours'] = '0'
frequent_location_df['week_bfr_1_day'] = '0'
frequent_location_df['week_bfr_7_days'] = '0'

# %%
# Find most popular types from time exactly 7 days ago
for index, row in frequent_location_df.iterrows():
    row_weekday = row.weekday
    row_hour = row.hours
    row_mins = row.mins
    iterator = 340
    searching = True
    if(iterator+index < frequent_location_df.shape[0] - 1):
        while searching == True:  
            current_row = frequent_location_df.iloc[index + iterator]
            if(current_row.weekday == row_weekday):
                if(current_row.hours == row_hour):
                    if(current_row.mins == row_mins):
                        frequent_location_df.loc[index, 'week_bfr_4_hours'] = current_row.type_4_hours
                        frequent_location_df.loc[index, 'week_bfr_1_day'] = current_row.type_1_day
                        print(index, 'row updated normally')
                        break
            if(iterator >= 380 or iterator + index >= frequent_location_df.shape[0] - 1):
                frequent_location_df.loc[index, 'week_bfr_4_hours'] = current_row.type_4_hours
                frequent_location_df.loc[index, 'week_bfr_1_day'] = current_row.type_1_day
                frequent_location_df.loc[index, 'week_bfr_7_days'] = current_row.type_7_days
                searching = False
                print(index, 'row updated because lack of data')
            iterator += 1
    else:
        frequent_location_df.loc[index, 'week_bfr_4_hours'] = 0
        frequent_location_df.loc[index, 'week_bfr_1_day'] = 0
        frequent_location_df.loc[index, 'week_bfr_7_days'] = 0

frequent_location_df.to_csv('location_with_last_week_info.csv')
# Out:
# 0 row updated normally
# 1 row updated normally
# 2 row updated normally
# 3 row updated normally
# 4 row updated normally
# 5 row updated normally
# 6 row updated normally
# 7 row updated normally
# 8 row updated normally
# 9 row updated normally
# 10 row updated normally
# 11 row updated normally
# 12 row updated normally
# 13 row updated normally
# 14 row updated normally
# 15 row updated normally
# 16 row updated normally
# 17 row updated normally
# 18 row updated normally
# 19 row updated normally
# 20 row updated normally
# 21 row updated normally
# 22 row updated normally
# 23 row updated normally
# 24 row updated normally
# 25 row updated normally
# 26 row updated normally
# 27 row updated normally
# 28 row updated normally
# 29 row updated normally
# 30 row updated normally
# 31 row updated normally
# 32 row updated normally
# 33 row updated normally
# 34 row updated normally
# 35 row updated normally
# 36 row updated normally
# 37 row updated normally
# 38 row updated normally
# 39 row updated normally
# 40 row updated normally
# 41 row updated normally
# 42 row updated normally
# 43 row updated normally
# 44 row updated normally
# 45 row updated normally
# 46 row updated normally
# 47 row updated normally
# 48 row updated normally
# 49 row updated normally
# 50 row updated normally
# 51 row updated normally
# 52 row updated normally
# 53 row updated normally
# 54 row updated normally
# 55 row updated normally
# 56 row updated normally
# 57 row updated normally
# 58 row updated normally
# 59 row updated normally
# 60 row updated normally
# 61 row updated normally
# 62 row updated normally
# 63 row updated normally
# 64 row updated normally
# 65 row updated normally
# 66 row updated normally
# 67 row updated normally
# 68 row updated normally
# 69 row updated normally
# 70 row updated normally
# 71 row updated normally
# 72 row updated normally
# 73 row updated normally
# 74 row updated normally
# 75 row updated normally
# 76 row updated normally
# 77 row updated normally
# 78 row updated because lack of data
# 79 row updated normally
# 80 row updated normally
# 81 row updated normally
# 82 row updated normally
# 83 row updated normally
# 84 row updated normally
# 85 row updated normally
# 86 row updated normally
# 87 row updated normally
# 88 row updated normally
# 89 row updated normally
# 90 row updated normally
# 91 row updated normally
# 92 row updated normally
# 93 row updated normally
# 94 row updated normally
# 95 row updated normally
# 96 row updated normally
# 97 row updated normally
# 98 row updated normally
# 99 row updated normally
# 100 row updated normally
# 101 row updated normally
# 102 row updated normally
# 103 row updated normally
# 104 row updated normally
# 105 row updated normally
# 106 row updated normally
# 107 row updated normally
# 108 row updated normally
# 109 row updated normally
# 110 row updated normally
# 111 row updated normally
# 112 row updated normally
# 113 row updated normally
# 114 row updated normally
# 115 row updated normally
# 116 row updated normally
# 117 row updated normally
# 118 row updated normally
# 119 row updated normally
# 120 row updated normally
# 121 row updated normally
# 122 row updated normally
# 123 row updated normally
# 124 row updated normally
# 125 row updated normally
# 126 row updated normally
# 127 row updated normally
# 128 row updated normally
# 129 row updated normally
# 130 row updated normally
# 131 row updated normally
# 132 row updated normally
# 133 row updated normally
# 134 row updated normally
# 135 row updated normally
# 136 row updated normally
# 137 row updated normally
# 138 row updated normally
# 139 row updated normally
# 140 row updated normally
# 141 row updated normally
# 142 row updated normally
# 143 row updated normally
# 144 row updated normally
# 145 row updated normally
# 146 row updated normally
# 147 row updated normally
# 148 row updated normally
# 149 row updated normally
# 150 row updated normally
# 151 row updated because lack of data
# 152 row updated normally
# 153 row updated normally
# 154 row updated normally
# 155 row updated normally
# 156 row updated normally
# 157 row updated normally
# 158 row updated normally
# 159 row updated normally
# 160 row updated normally
# 161 row updated normally
# 162 row updated normally
# 163 row updated normally
# 164 row updated normally
# 165 row updated normally
# 166 row updated normally
# 167 row updated normally
# 168 row updated normally
# 169 row updated normally
# 170 row updated normally
# 171 row updated normally
# 172 row updated normally
# 173 row updated normally
# 174 row updated normally
# 175 row updated normally
# 176 row updated normally
# 177 row updated normally
# 178 row updated normally
# 179 row updated normally
# 180 row updated normally
# 181 row updated normally
# 182 row updated normally
# 183 row updated normally
# 184 row updated normally
# 185 row updated normally
# 186 row updated normally
# 187 row updated normally
# 188 row updated normally
# 189 row updated normally
# 190 row updated normally
# 191 row updated normally
# 192 row updated normally
# 193 row updated normally
# 194 row updated normally
# 195 row updated normally
# 196 row updated normally
# 197 row updated normally
# 198 row updated normally
# 199 row updated normally
# 200 row updated normally
# 201 row updated normally
# 202 row updated normally
# 203 row updated normally
# 204 row updated normally
# 205 row updated normally
# 206 row updated normally
# 207 row updated normally
# 208 row updated normally
# 209 row updated normally
# 210 row updated normally
# 211 row updated normally
# 212 row updated normally
# 213 row updated normally
# 214 row updated normally
# 215 row updated normally
# 216 row updated normally
# 217 row updated normally
# 218 row updated normally
# 219 row updated normally
# 220 row updated normally
# 221 row updated normally
# 222 row updated normally
# 223 row updated normally
# 224 row updated normally
# 225 row updated normally
# 226 row updated normally
# 227 row updated normally
# 228 row updated normally
# 229 row updated normally
# 230 row updated normally
# 231 row updated normally
# 232 row updated normally
# 233 row updated normally
# 234 row updated normally
# 235 row updated normally
# 236 row updated normally
# 237 row updated normally
# 238 row updated normally
# 239 row updated normally
# 240 row updated normally
# 241 row updated normally
# 242 row updated normally
# 243 row updated normally
# 244 row updated normally
# 245 row updated normally
# 246 row updated normally
# 247 row updated normally
# 248 row updated normally
# 249 row updated normally
# 250 row updated normally
# 251 row updated normally
# 252 row updated normally
# 253 row updated normally
# 254 row updated normally
# 255 row updated normally
# 256 row updated because lack of data
# 257 row updated normally
# 258 row updated normally
# 259 row updated normally
# 260 row updated normally
# 261 row updated normally
# 262 row updated normally
# 263 row updated normally
# 264 row updated normally
# 265 row updated normally
# 266 row updated normally
# 267 row updated normally
# 268 row updated normally
# 269 row updated normally
# 270 row updated normally
# 271 row updated normally
# 272 row updated normally
# 273 row updated normally
# 274 row updated normally
# 275 row updated normally
# 276 row updated normally
# 277 row updated normally
# 278 row updated normally
# 279 row updated normally
# 280 row updated normally
# 281 row updated normally
# 282 row updated normally
# 283 row updated normally
# 284 row updated normally
# 285 row updated normally
# 286 row updated normally
# 287 row updated normally
# 288 row updated normally
# 289 row updated normally
# 290 row updated normally
# 291 row updated normally
# 292 row updated normally
# 293 row updated normally
# 294 row updated because lack of data
# 295 row updated normally
# 296 row updated normally
# 297 row updated normally
# 298 row updated normally
# 299 row updated normally
# 300 row updated normally
# 301 row updated normally
# 302 row updated normally
# 303 row updated normally
# 304 row updated normally
# 305 row updated normally
# 306 row updated normally
# 307 row updated normally
# 308 row updated normally
# 309 row updated normally
# 310 row updated normally
# 311 row updated normally
# 312 row updated normally
# 313 row updated normally
# 314 row updated normally
# 315 row updated normally
# 316 row updated normally
# 317 row updated normally
# 318 row updated normally
# 319 row updated normally
# 320 row updated normally
# 321 row updated because lack of data
# 322 row updated normally
# 323 row updated normally
# 324 row updated normally
# 325 row updated normally
# 326 row updated normally
# 327 row updated normally
# 328 row updated normally
# 329 row updated normally
# 330 row updated normally
# 331 row updated normally
# 332 row updated normally
# 333 row updated normally
# 334 row updated normally
# 335 row updated normally
# 336 row updated normally
# 337 row updated normally
# 338 row updated normally
# 339 row updated normally
# 340 row updated normally
# 341 row updated normally
# 342 row updated normally
# 343 row updated normally
# 344 row updated normally
# 345 row updated normally
# 346 row updated because lack of data
# 347 row updated normally
# 348 row updated because lack of data
# 349 row updated normally
# 350 row updated normally
# 351 row updated normally
# 352 row updated normally
# 353 row updated normally
# 354 row updated normally
# 355 row updated normally
# 356 row updated normally
# 357 row updated normally
# 358 row updated normally
# 359 row updated because lack of data
# 360 row updated because lack of data
# 361 row updated normally
# 362 row updated normally
# 363 row updated because lack of data
# 364 row updated normally
# 365 row updated normally
# 366 row updated normally
# 367 row updated normally
# 368 row updated normally
# 369 row updated normally
# 370 row updated normally
# 371 row updated normally
# 372 row updated normally
# 373 row updated normally
# 374 row updated normally
# 375 row updated normally
# 376 row updated normally
# 377 row updated normally
# 378 row updated normally
# 379 row updated normally
# 380 row updated normally
# 381 row updated normally
# 382 row updated normally
# 383 row updated normally
# 384 row updated normally
# 385 row updated because lack of data
# 386 row updated because lack of data
# 387 row updated because lack of data
# 388 row updated because lack of data
# 389 row updated normally
# 390 row updated normally
# 391 row updated normally
# 392 row updated normally
# 393 row updated normally
# 394 row updated normally
# 395 row updated normally
# 396 row updated normally
# 397 row updated normally
# 398 row updated normally
# 399 row updated normally
# 400 row updated normally
# 401 row updated normally
# 402 row updated normally
# 403 row updated normally
# 404 row updated normally
# 405 row updated normally
# 406 row updated normally
# 407 row updated normally
# 408 row updated normally
# 409 row updated normally
# 410 row updated normally
# 411 row updated normally
# 412 row updated normally
# 413 row updated normally
# 414 row updated normally
# 415 row updated normally
# 416 row updated normally
# 417 row updated normally
# 418 row updated normally
# 419 row updated normally
# 420 row updated normally
# 421 row updated normally
# 422 row updated normally
# 423 row updated normally
# 424 row updated normally
# 425 row updated normally
# 426 row updated normally
# 427 row updated normally
# 428 row updated normally
# 429 row updated normally
# 430 row updated normally
# 431 row updated normally
# 432 row updated normally
# 433 row updated normally
# 434 row updated normally
# 435 row updated because lack of data
# 436 row updated normally
# 437 row updated normally
# 438 row updated normally
# 439 row updated normally
# 440 row updated normally
# 441 row updated because lack of data
# 442 row updated because lack of data
# 443 row updated because lack of data
# 444 row updated normally
# 445 row updated normally
# 446 row updated normally
# 447 row updated normally
# 448 row updated normally
# 449 row updated normally
# 450 row updated normally
# 451 row updated normally
# 452 row updated normally
# 453 row updated normally
# 454 row updated normally
# 455 row updated normally
# 456 row updated normally
# 457 row updated normally
# 458 row updated normally
# 459 row updated normally
# 460 row updated normally
# 461 row updated normally
# 462 row updated normally
# 463 row updated normally
# 464 row updated normally
# 465 row updated normally
# 466 row updated normally
# 467 row updated normally
# 468 row updated normally
# 469 row updated normally
# 470 row updated normally
# 471 row updated normally
# 472 row updated normally
# 473 row updated normally
# 474 row updated normally
# 475 row updated normally
# 476 row updated because lack of data
# 477 row updated normally
# 478 row updated normally
# 479 row updated normally
# 480 row updated normally
# 481 row updated normally
# 482 row updated normally
# 483 row updated normally
# 484 row updated normally
# 485 row updated normally
# 486 row updated normally
# 487 row updated normally
# 488 row updated normally
# 489 row updated normally
# 490 row updated normally
# 491 row updated normally
# 492 row updated normally
# 493 row updated normally
# 494 row updated normally
# 495 row updated normally
# 496 row updated normally
# 497 row updated normally
# 498 row updated normally
# 499 row updated normally
# 500 row updated normally
# 501 row updated normally
# 502 row updated normally
# 503 row updated normally
# 504 row updated normally
# 505 row updated normally
# 506 row updated normally
# 507 row updated normally
# 508 row updated normally
# 509 row updated normally
# 510 row updated normally
# 511 row updated normally
# 512 row updated normally
# 513 row updated normally
# 514 row updated normally
# 515 row updated normally
# 516 row updated normally
# 517 row updated normally
# 518 row updated normally
# 519 row updated normally
# 520 row updated normally
# 521 row updated normally
# 522 row updated normally
# 523 row updated normally
# 524 row updated normally
# 525 row updated normally
# 526 row updated normally
# 527 row updated normally
# 528 row updated normally
# 529 row updated normally
# 530 row updated normally
# 531 row updated normally
# 532 row updated normally
# 533 row updated normally
# 534 row updated normally
# 535 row updated normally
# 536 row updated normally
# 537 row updated normally
# 538 row updated normally
# 539 row updated normally
# 540 row updated normally
# 541 row updated normally
# 542 row updated normally
# 543 row updated normally
# 544 row updated normally
# 545 row updated normally
# 546 row updated normally
# 547 row updated normally
# 548 row updated normally
# 549 row updated normally
# 550 row updated normally
# 551 row updated normally
# 552 row updated normally
# 553 row updated normally
# 554 row updated normally
# 555 row updated normally
# 556 row updated normally
# 557 row updated normally
# 558 row updated normally
# 559 row updated normally
# 560 row updated normally
# 561 row updated normally
# 562 row updated normally
# 563 row updated normally
# 564 row updated normally
# 565 row updated normally
# 566 row updated normally
# 567 row updated normally
# 568 row updated normally
# 569 row updated normally
# 570 row updated normally
# 571 row updated normally
# 572 row updated normally
# 573 row updated normally
# 574 row updated normally
# 575 row updated normally
# 576 row updated normally
# 577 row updated normally
# 578 row updated normally
# 579 row updated normally
# 580 row updated normally
# 581 row updated normally
# 582 row updated normally
# 583 row updated normally
# 584 row updated normally
# 585 row updated normally
# 586 row updated normally
# 587 row updated normally
# 588 row updated normally
# 589 row updated normally
# 590 row updated normally
# 591 row updated normally
# 592 row updated normally
# 593 row updated normally
# 594 row updated normally
# 595 row updated normally
# 596 row updated normally
# 597 row updated normally
# 598 row updated normally
# 599 row updated normally
# 600 row updated normally
# 601 row updated normally
# 602 row updated because lack of data
# 603 row updated normally
# 604 row updated normally
# 605 row updated normally
# 606 row updated normally
# 607 row updated normally
# 608 row updated normally
# 609 row updated normally
# 610 row updated normally
# 611 row updated normally
# 612 row updated normally
# 613 row updated normally
# 614 row updated normally
# 615 row updated normally
# 616 row updated normally
# 617 row updated normally
# 618 row updated normally
# 619 row updated normally
# 620 row updated normally
# 621 row updated normally
# 622 row updated normally
# 623 row updated normally
# 624 row updated normally
# 625 row updated normally
# 626 row updated normally
# 627 row updated normally
# 628 row updated normally
# 629 row updated because lack of data
# 630 row updated normally
# 631 row updated because lack of data
# 632 row updated normally
# 633 row updated normally
# 634 row updated because lack of data
# 635 row updated normally
# 636 row updated normally
# 637 row updated normally
# 638 row updated normally
# 639 row updated normally
# 640 row updated normally
# 641 row updated normally
# 642 row updated normally
# 643 row updated normally
# 644 row updated normally
# 645 row updated normally
# 646 row updated normally
# 647 row updated normally
# 648 row updated normally
# 649 row updated normally
# 650 row updated normally
# 651 row updated normally
# 652 row updated normally
# 653 row updated normally
# 654 row updated normally
# 655 row updated normally
# 656 row updated normally
# 657 row updated normally
# 658 row updated normally
# 659 row updated normally
# 660 row updated normally
# 661 row updated normally
# 662 row updated normally
# 663 row updated normally
# 664 row updated normally
# 665 row updated normally
# 666 row updated normally
# 667 row updated normally
# 668 row updated normally
# 669 row updated normally
# 670 row updated normally
# 671 row updated normally
# 672 row updated normally
# 673 row updated normally
# 674 row updated normally
# 675 row updated normally
# 676 row updated normally
# 677 row updated normally
# 678 row updated normally
# 679 row updated normally
# 680 row updated normally
# 681 row updated normally
# 682 row updated normally
# 683 row updated normally
# 684 row updated normally
# 685 row updated normally
# 686 row updated normally
# 687 row updated normally
# 688 row updated normally
# 689 row updated normally
# 690 row updated normally
# 691 row updated normally
# 692 row updated normally
# 693 row updated normally
# 694 row updated normally
# 695 row updated normally
# 696 row updated normally
# 697 row updated normally
# 698 row updated normally
# 699 row updated normally
# 700 row updated normally
# 701 row updated normally
# 702 row updated normally
# 703 row updated normally
# 704 row updated normally
# 705 row updated normally
# 706 row updated normally
# 707 row updated normally
# 708 row updated normally
# 709 row updated normally
# 710 row updated normally
# 711 row updated normally
# 712 row updated normally
# 713 row updated normally
# 714 row updated normally
# 715 row updated normally
# 716 row updated normally
# 717 row updated normally
# 718 row updated normally
# 719 row updated normally
# 720 row updated normally
# 721 row updated normally
# 722 row updated normally
# 723 row updated normally
# 724 row updated normally
# 725 row updated normally
# 726 row updated normally
# 727 row updated normally
# 728 row updated normally
# 729 row updated normally
# 730 row updated normally
# 731 row updated normally
# 732 row updated normally
# 733 row updated normally
# 734 row updated normally
# 735 row updated normally
# 736 row updated normally
# 737 row updated normally
# 738 row updated normally
# 739 row updated normally
# 740 row updated normally
# 741 row updated normally
# 742 row updated normally
# 743 row updated normally
# 744 row updated normally
# 745 row updated normally
# 746 row updated because lack of data
# 747 row updated normally
# 748 row updated normally
# 749 row updated normally
# 750 row updated normally
# 751 row updated normally
# 752 row updated normally
# 753 row updated normally
# 754 row updated normally
# 755 row updated normally
# 756 row updated normally
# 757 row updated normally
# 758 row updated normally
# 759 row updated normally
# 760 row updated normally
# 761 row updated normally
# 762 row updated normally
# 763 row updated normally
# 764 row updated normally
# 765 row updated normally
# 766 row updated normally
# 767 row updated normally
# 768 row updated normally
# 769 row updated normally
# 770 row updated normally
# 771 row updated normally
# 772 row updated because lack of data
# 773 row updated normally
# 774 row updated because lack of data
# 775 row updated normally
# 776 row updated normally
# 777 row updated normally
# 778 row updated normally
# 779 row updated normally
# 780 row updated normally
# 781 row updated normally
# 782 row updated normally
# 783 row updated normally
# 784 row updated normally
# 785 row updated normally
# 786 row updated normally
# 787 row updated normally
# 788 row updated because lack of data
# 789 row updated normally
# 790 row updated normally
# 791 row updated normally
# 792 row updated normally
# 793 row updated normally
# 794 row updated normally
# 795 row updated normally
# 796 row updated normally
# 797 row updated normally
# 798 row updated normally
# 799 row updated normally
# 800 row updated because lack of data
# 801 row updated normally
# 802 row updated normally
# 803 row updated normally
# 804 row updated normally
# 805 row updated normally
# 806 row updated normally
# 807 row updated normally
# 808 row updated normally
# 809 row updated normally
# 810 row updated normally
# 811 row updated normally
# 812 row updated normally
# 813 row updated normally
# 814 row updated normally
# 815 row updated normally
# 816 row updated normally
# 817 row updated normally
# 818 row updated normally
# 819 row updated normally
# 820 row updated because lack of data
# 821 row updated normally
# 822 row updated normally
# 823 row updated normally
# 824 row updated normally
# 825 row updated normally
# 826 row updated normally
# 827 row updated normally
# 828 row updated normally
# 829 row updated normally
# 830 row updated normally
# 831 row updated normally
# 832 row updated normally
# 833 row updated normally
# 834 row updated normally
# 835 row updated normally
# 836 row updated normally
# 837 row updated normally
# 838 row updated normally
# 839 row updated normally
# 840 row updated normally
# 841 row updated normally
# 842 row updated normally
# 843 row updated normally
# 844 row updated normally
# 845 row updated normally
# 846 row updated normally
# 847 row updated normally
# 848 row updated normally
# 849 row updated normally
# 850 row updated normally
# 851 row updated normally
# 852 row updated normally
# 853 row updated normally
# 854 row updated normally
# 855 row updated normally
# 856 row updated normally
# 857 row updated normally
# 858 row updated normally
# 859 row updated normally
# 860 row updated normally
# 861 row updated normally
# 862 row updated normally
# 863 row updated normally
# 864 row updated normally
# 865 row updated normally
# 866 row updated normally
# 867 row updated normally
# 868 row updated normally
# 869 row updated because lack of data
# 870 row updated normally
# 871 row updated normally
# 872 row updated normally
# 873 row updated normally
# 874 row updated normally
# 875 row updated normally
# 876 row updated normally
# 877 row updated normally
# 878 row updated normally
# 879 row updated normally
# 880 row updated normally
# 881 row updated normally
# 882 row updated normally
# 883 row updated normally
# 884 row updated normally
# 885 row updated normally
# 886 row updated normally
# 887 row updated normally
# 888 row updated normally
# 889 row updated normally
# 890 row updated normally
# 891 row updated normally
# 892 row updated normally
# 893 row updated normally
# 894 row updated normally
# 895 row updated normally
# 896 row updated normally
# 897 row updated normally
# 898 row updated normally
# 899 row updated normally
# 900 row updated normally
# 901 row updated because lack of data
# 902 row updated normally
# 903 row updated because lack of data
# 904 row updated normally
# 905 row updated normally
# 906 row updated normally
# 907 row updated normally
# 908 row updated normally
# 909 row updated normally
# 910 row updated normally
# 911 row updated normally
# 912 row updated normally
# 913 row updated normally
# 914 row updated normally
# 915 row updated normally
# 916 row updated normally
# 917 row updated normally
# 918 row updated normally
# 919 row updated because lack of data
# 920 row updated normally
# 921 row updated normally
# 922 row updated normally
# 923 row updated normally
# 924 row updated normally
# 925 row updated normally
# 926 row updated normally
# 927 row updated normally
# 928 row updated normally
# 929 row updated normally
# 930 row updated normally
# 931 row updated normally
# 932 row updated normally
# 933 row updated normally
# 934 row updated normally
# 935 row updated normally
# 936 row updated normally
# 937 row updated normally
# 938 row updated normally
# 939 row updated normally
# 940 row updated normally
# 941 row updated normally
# 942 row updated normally
# 943 row updated normally
# 944 row updated normally
# 945 row updated normally
# 946 row updated normally
# 947 row updated normally
# 948 row updated normally
# 949 row updated normally
# 950 row updated normally
# 951 row updated normally
# 952 row updated normally
# 953 row updated normally
# 954 row updated normally
# 955 row updated normally
# 956 row updated normally
# 957 row updated normally
# 958 row updated normally
# 959 row updated normally
# 960 row updated normally
# 961 row updated normally
# 962 row updated normally
# 963 row updated normally
# 964 row updated normally
# 965 row updated normally
# 966 row updated normally
# 967 row updated normally
# 968 row updated normally
# 969 row updated normally
# 970 row updated normally
# 971 row updated normally
# 972 row updated normally
# 973 row updated normally
# 974 row updated because lack of data
# 975 row updated normally
# 976 row updated normally
# 977 row updated normally
# 978 row updated normally
# 979 row updated normally
# 980 row updated normally
# 981 row updated normally
# 982 row updated normally
# 983 row updated normally
# 984 row updated normally
# 985 row updated normally
# 986 row updated normally
# 987 row updated normally
# 988 row updated normally
# 989 row updated normally
# 990 row updated normally
# 991 row updated normally
# 992 row updated normally
# 993 row updated normally
# 994 row updated normally
# 995 row updated normally
# 996 row updated normally
# 997 row updated normally
# 998 row updated normally
# 999 row updated normally
# 1000 row updated normally
# 1001 row updated normally
# 1002 row updated normally
# 1003 row updated normally
# 1004 row updated normally
# 1005 row updated normally
# 1006 row updated normally
# 1007 row updated normally
# 1008 row updated normally
# 1009 row updated normally
# 1010 row updated normally
# 1011 row updated normally
# 1012 row updated normally
# 1013 row updated normally
# 1014 row updated normally
# 1015 row updated normally
# 1016 row updated normally
# 1017 row updated normally
# 1018 row updated normally
# 1019 row updated normally
# 1020 row updated normally
# 1021 row updated normally
# 1022 row updated normally
# 1023 row updated normally
# 1024 row updated normally
# 1025 row updated normally
# 1026 row updated normally
# 1027 row updated normally
# 1028 row updated normally
# 1029 row updated normally
# 1030 row updated normally
# 1031 row updated normally
# 1032 row updated normally
# 1033 row updated normally
# 1034 row updated normally
# 1035 row updated normally
# 1036 row updated normally
# 1037 row updated normally
# 1038 row updated normally
# 1039 row updated normally
# 1040 row updated normally
# 1041 row updated normally
# 1042 row updated normally
# 1043 row updated normally
# 1044 row updated normally
# 1045 row updated normally
# 1046 row updated normally
# 1047 row updated normally
# 1048 row updated normally
# 1049 row updated normally
# 1050 row updated normally
# 1051 row updated normally
# 1052 row updated normally
# 1053 row updated normally
# 1054 row updated normally
# 1055 row updated normally
# 1056 row updated normally
# 1057 row updated normally
# 1058 row updated normally
# 1059 row updated normally
# 1060 row updated normally
# 1061 row updated normally
# 1062 row updated normally
# 1063 row updated normally
# 1064 row updated normally
# 1065 row updated normally
# 1066 row updated normally
# 1067 row updated normally
# 1068 row updated normally
# 1069 row updated normally
# 1070 row updated normally
# 1071 row updated normally
# 1072 row updated normally
# 1073 row updated normally
# 1074 row updated normally
# 1075 row updated normally
# 1076 row updated normally
# 1077 row updated normally
# 1078 row updated normally
# 1079 row updated normally
# 1080 row updated normally
# 1081 row updated normally
# 1082 row updated normally
# 1083 row updated normally
# 1084 row updated normally
# 1085 row updated normally
# 1086 row updated normally
# 1087 row updated normally
# 1088 row updated normally
# 1089 row updated normally
# 1090 row updated normally
# 1091 row updated normally
# 1092 row updated because lack of data
# 1093 row updated because lack of data
# 1094 row updated normally
# 1095 row updated normally
# 1096 row updated normally
# 1097 row updated normally
# 1098 row updated normally
# 1099 row updated normally
# 1100 row updated normally
# 1101 row updated because lack of data
# 1102 row updated normally
# 1103 row updated normally
# 1104 row updated normally
# 1105 row updated normally
# 1106 row updated normally
# 1107 row updated normally
# 1108 row updated normally
# 1109 row updated normally
# 1110 row updated normally
# 1111 row updated normally
# 1112 row updated normally
# 1113 row updated normally
# 1114 row updated normally
# 1115 row updated normally
# 1116 row updated normally
# 1117 row updated normally
# 1118 row updated normally
# 1119 row updated normally
# 1120 row updated normally
# 1121 row updated normally
# 1122 row updated normally
# 1123 row updated normally
# 1124 row updated normally
# 1125 row updated normally
# 1126 row updated normally
# 1127 row updated normally
# 1128 row updated normally
# 1129 row updated normally
# 1130 row updated normally
# 1131 row updated normally
# 1132 row updated normally
# 1133 row updated normally
# 1134 row updated normally
# 1135 row updated normally
# 1136 row updated normally
# 1137 row updated normally
# 1138 row updated normally
# 1139 row updated normally
# 1140 row updated normally
# 1141 row updated normally
# 1142 row updated normally
# 1143 row updated normally
# 1144 row updated normally
# 1145 row updated normally
# 1146 row updated normally
# 1147 row updated normally
# 1148 row updated normally
# 1149 row updated normally
# 1150 row updated normally
# 1151 row updated normally
# 1152 row updated normally
# 1153 row updated normally
# 1154 row updated normally
# 1155 row updated normally
# 1156 row updated normally
# 1157 row updated normally
# 1158 row updated normally
# 1159 row updated normally
# 1160 row updated normally
# 1161 row updated normally
# 1162 row updated normally
# 1163 row updated normally
# 1164 row updated normally
# 1165 row updated normally
# 1166 row updated normally
# 1167 row updated normally
# 1168 row updated normally
# 1169 row updated normally
# 1170 row updated normally
# 1171 row updated normally
# 1172 row updated normally
# 1173 row updated normally
# 1174 row updated normally
# 1175 row updated normally
# 1176 row updated normally
# 1177 row updated normally
# 1178 row updated normally
# 1179 row updated normally
# 1180 row updated normally
# 1181 row updated normally
# 1182 row updated normally
# 1183 row updated normally
# 1184 row updated normally
# 1185 row updated normally
# 1186 row updated normally
# 1187 row updated normally
# 1188 row updated normally
# 1189 row updated normally
# 1190 row updated normally
# 1191 row updated normally
# 1192 row updated normally
# 1193 row updated normally
# 1194 row updated because lack of data
# 1195 row updated normally
# 1196 row updated normally
# 1197 row updated normally
# 1198 row updated normally
# 1199 row updated normally
# 1200 row updated normally
# 1201 row updated normally
# 1202 row updated normally
# 1203 row updated normally
# 1204 row updated normally
# 1205 row updated normally
# 1206 row updated normally
# 1207 row updated normally
# 1208 row updated normally
# 1209 row updated normally
# 1210 row updated normally
# 1211 row updated normally
# 1212 row updated normally
# 1213 row updated normally
# 1214 row updated normally
# 1215 row updated normally
# 1216 row updated normally
# 1217 row updated normally
# 1218 row updated normally
# 1219 row updated normally
# 1220 row updated normally
# 1221 row updated normally
# 1222 row updated normally
# 1223 row updated because lack of data
# 1224 row updated normally
# 1225 row updated normally
# 1226 row updated normally
# 1227 row updated normally
# 1228 row updated normally
# 1229 row updated normally
# 1230 row updated normally
# 1231 row updated normally
# 1232 row updated normally
# 1233 row updated normally
# 1234 row updated normally
# 1235 row updated because lack of data
# 1236 row updated normally
# 1237 row updated normally
# 1238 row updated normally
# 1239 row updated normally
# 1240 row updated normally
# 1241 row updated normally
# 1242 row updated normally
# 1243 row updated normally
# 1244 row updated because lack of data
# 1245 row updated normally
# 1246 row updated normally
# 1247 row updated because lack of data
# 1248 row updated normally
# 1249 row updated normally
# 1250 row updated normally
# 1251 row updated normally
# 1252 row updated normally
# 1253 row updated normally
# 1254 row updated normally
# 1255 row updated normally
# 1256 row updated normally
# 1257 row updated normally
# 1258 row updated normally
# 1259 row updated normally
# 1260 row updated normally
# 1261 row updated normally
# 1262 row updated normally
# 1263 row updated normally
# 1264 row updated normally
# 1265 row updated normally
# 1266 row updated normally
# 1267 row updated normally
# 1268 row updated normally
# 1269 row updated normally
# 1270 row updated normally
# 1271 row updated normally
# 1272 row updated normally
# 1273 row updated normally
# 1274 row updated normally
# 1275 row updated normally
# 1276 row updated normally
# 1277 row updated normally
# 1278 row updated normally
# 1279 row updated normally
# 1280 row updated normally
# 1281 row updated normally
# 1282 row updated normally
# 1283 row updated normally
# 1284 row updated normally
# 1285 row updated normally
# 1286 row updated normally
# 1287 row updated normally
# 1288 row updated normally
# 1289 row updated normally
# 1290 row updated normally
# 1291 row updated normally
# 1292 row updated normally
# 1293 row updated normally
# 1294 row updated normally
# 1295 row updated normally
# 1296 row updated normally
# 1297 row updated normally
# 1298 row updated normally
# 1299 row updated normally
# 1300 row updated normally
# 1301 row updated normally
# 1302 row updated normally
# 1303 row updated normally
# 1304 row updated normally
# 1305 row updated normally
# 1306 row updated normally
# 1307 row updated normally
# 1308 row updated normally
# 1309 row updated normally
# 1310 row updated normally
# 1311 row updated normally
# 1312 row updated normally
# 1313 row updated normally
# 1314 row updated normally
# 1315 row updated normally
# 1316 row updated normally
# 1317 row updated normally
# 1318 row updated normally
# 1319 row updated normally
# 1320 row updated normally
# 1321 row updated normally
# 1322 row updated normally
# 1323 row updated normally
# 1324 row updated normally
# 1325 row updated normally
# 1326 row updated normally
# 1327 row updated normally
# 1328 row updated normally
# 1329 row updated normally
# 1330 row updated normally
# 1331 row updated normally
# 1332 row updated normally
# 1333 row updated normally
# 1334 row updated normally
# 1335 row updated normally
# 1336 row updated normally
# 1337 row updated normally
# 1338 row updated normally
# 1339 row updated normally
# 1340 row updated normally
# 1341 row updated normally
# 1342 row updated normally
# 1343 row updated normally
# 1344 row updated normally
# 1345 row updated normally
# 1346 row updated normally
# 1347 row updated normally
# 1348 row updated normally
# 1349 row updated normally
# 1350 row updated normally
# 1351 row updated normally
# 1352 row updated normally
# 1353 row updated normally
# 1354 row updated normally
# 1355 row updated normally
# 1356 row updated normally
# 1357 row updated normally
# 1358 row updated normally
# 1359 row updated normally
# 1360 row updated normally
# 1361 row updated normally
# 1362 row updated normally
# 1363 row updated normally
# 1364 row updated normally
# 1365 row updated normally
# 1366 row updated normally
# 1367 row updated normally
# 1368 row updated normally
# 1369 row updated normally
# 1370 row updated normally
# 1371 row updated normally
# 1372 row updated normally
# 1373 row updated normally
# 1374 row updated normally
# 1375 row updated normally
# 1376 row updated normally
# 1377 row updated normally
# 1378 row updated normally
# 1379 row updated normally
# 1380 row updated normally
# 1381 row updated normally
# 1382 row updated normally
# 1383 row updated normally
# 1384 row updated normally
# 1385 row updated normally
# 1386 row updated normally
# 1387 row updated normally
# 1388 row updated normally
# 1389 row updated normally
# 1390 row updated normally
# 1391 row updated normally
# 1392 row updated normally
# 1393 row updated normally
# 1394 row updated normally
# 1395 row updated normally
# 1396 row updated normally
# 1397 row updated normally
# 1398 row updated normally
# 1399 row updated normally
# 1400 row updated normally
# 1401 row updated normally
# 1402 row updated normally
# 1403 row updated normally
# 1404 row updated normally
# 1405 row updated normally
# 1406 row updated normally
# 1407 row updated normally
# 1408 row updated normally
# 1409 row updated normally
# 1410 row updated normally
# 1411 row updated normally
# 1412 row updated normally
# 1413 row updated normally
# 1414 row updated normally
# 1415 row updated normally
# 1416 row updated normally
# 1417 row updated normally
# 1418 row updated normally
# 1419 row updated normally
# 1420 row updated normally
# 1421 row updated normally
# 1422 row updated normally
# 1423 row updated normally
# 1424 row updated normally
# 1425 row updated normally
# 1426 row updated normally
# 1427 row updated normally
# 1428 row updated normally
# 1429 row updated normally
# 1430 row updated normally
# 1431 row updated normally
# 1432 row updated normally
# 1433 row updated normally
# 1434 row updated normally
# 1435 row updated normally
# 1436 row updated normally
# 1437 row updated normally
# 1438 row updated normally
# 1439 row updated normally
# 1440 row updated normally
# 1441 row updated normally
# 1442 row updated normally
# 1443 row updated normally
# 1444 row updated normally
# 1445 row updated normally
# 1446 row updated normally
# 1447 row updated normally
# 1448 row updated normally
# 1449 row updated normally
# 1450 row updated normally
# 1451 row updated normally
# 1452 row updated normally
# 1453 row updated normally
# 1454 row updated normally
# 1455 row updated normally
# 1456 row updated normally
# 1457 row updated normally
# 1458 row updated normally
# 1459 row updated normally
# 1460 row updated normally
# 1461 row updated normally
# 1462 row updated normally
# 1463 row updated normally
# 1464 row updated normally
# 1465 row updated normally
# 1466 row updated normally
# 1467 row updated normally
# 1468 row updated normally
# 1469 row updated normally
# 1470 row updated normally
# 1471 row updated normally
# 1472 row updated normally
# 1473 row updated normally
# 1474 row updated because lack of data
# 1475 row updated because lack of data
# 1476 row updated because lack of data
# 1477 row updated because lack of data
# 1478 row updated because lack of data
# 1479 row updated because lack of data
# 1480 row updated because lack of data
# 1481 row updated because lack of data
# 1482 row updated because lack of data
# 1483 row updated because lack of data
# 1484 row updated because lack of data
# 1485 row updated because lack of data
# 1486 row updated because lack of data
# 1487 row updated because lack of data
# 1488 row updated because lack of data
# 1489 row updated because lack of data
# 1490 row updated because lack of data
# 1491 row updated because lack of data
# 1492 row updated because lack of data
# 1493 row updated because lack of data
# 1494 row updated because lack of data
# 1495 row updated because lack of data
# 1496 row updated because lack of data
# 1497 row updated because lack of data
# 1498 row updated because lack of data
# 1499 row updated because lack of data
# 1500 row updated because lack of data
# 1501 row updated because lack of data
# 1502 row updated because lack of data
# 1503 row updated because lack of data
# 1504 row updated because lack of data
# 1505 row updated because lack of data
# 1506 row updated because lack of data
# 1507 row updated normally
# 1508 row updated normally
# 1509 row updated normally
# 1510 row updated normally
# 1511 row updated normally
# 1512 row updated normally
# 1513 row updated normally
# 1514 row updated normally
# 1515 row updated normally
# 1516 row updated normally
# 1517 row updated normally
# 1518 row updated normally
# 1519 row updated normally
# 1520 row updated normally
# 1521 row updated normally
# 1522 row updated normally
# 1523 row updated normally
# 1524 row updated normally
# 1525 row updated normally
# 1526 row updated normally
# 1527 row updated normally
# 1528 row updated normally
# 1529 row updated normally
# 1530 row updated normally
# 1531 row updated normally
# 1532 row updated normally
# 1533 row updated normally
# 1534 row updated normally
# 1535 row updated normally
# 1536 row updated normally
# 1537 row updated normally
# 1538 row updated normally
# 1539 row updated normally
# 1540 row updated normally
# 1541 row updated normally
# 1542 row updated normally
# 1543 row updated normally
# 1544 row updated normally
# 1545 row updated normally
# 1546 row updated normally
# 1547 row updated normally
# 1548 row updated normally
# 1549 row updated normally
# 1550 row updated normally
# 1551 row updated normally
# 1552 row updated normally
# 1553 row updated normally
# 1554 row updated normally
# 1555 row updated normally
# 1556 row updated normally
# 1557 row updated normally
# 1558 row updated normally
# 1559 row updated normally
# 1560 row updated normally
# 1561 row updated normally
# 1562 row updated normally
# 1563 row updated because lack of data
# 1564 row updated normally
# 1565 row updated because lack of data
# 1566 row updated normally
# 1567 row updated normally
# 1568 row updated normally
# 1569 row updated normally
# 1570 row updated normally
# 1571 row updated normally
# 1572 row updated normally
# 1573 row updated because lack of data
# 1574 row updated normally
# 1575 row updated normally
# 1576 row updated normally
# 1577 row updated normally
# 1578 row updated normally
# 1579 row updated normally
# 1580 row updated normally
# 1581 row updated normally
# 1582 row updated normally
# 1583 row updated normally
# 1584 row updated normally
# 1585 row updated normally
# 1586 row updated normally
# 1587 row updated normally
# 1588 row updated normally
# 1589 row updated normally
# 1590 row updated normally
# 1591 row updated normally
# 1592 row updated normally
# 1593 row updated normally
# 1594 row updated normally
# 1595 row updated normally
# 1596 row updated normally
# 1597 row updated normally
# 1598 row updated normally
# 1599 row updated normally
# 1600 row updated normally
# 1601 row updated normally
# 1602 row updated normally
# 1603 row updated normally
# 1604 row updated normally
# 1605 row updated normally
# 1606 row updated normally
# 1607 row updated normally
# 1608 row updated normally
# 1609 row updated normally
# 1610 row updated normally
# 1611 row updated normally
# 1612 row updated normally
# 1613 row updated normally
# 1614 row updated normally
# 1615 row updated normally
# 1616 row updated normally
# 1617 row updated normally
# 1618 row updated normally
# 1619 row updated normally
# 1620 row updated normally
# 1621 row updated normally
# 1622 row updated because lack of data
# 1623 row updated normally
# 1624 row updated normally
# 1625 row updated normally
# 1626 row updated normally
# 1627 row updated normally
# 1628 row updated normally
# 1629 row updated normally
# 1630 row updated normally
# 1631 row updated normally
# 1632 row updated normally
# 1633 row updated normally
# 1634 row updated normally
# 1635 row updated normally
# 1636 row updated normally
# 1637 row updated normally
# 1638 row updated because lack of data
# 1639 row updated normally
# 1640 row updated normally
# 1641 row updated normally
# 1642 row updated normally
# 1643 row updated normally
# 1644 row updated normally
# 1645 row updated normally
# 1646 row updated normally
# 1647 row updated normally
# 1648 row updated normally
# 1649 row updated normally
# 1650 row updated normally
# 1651 row updated normally
# 1652 row updated normally
# 1653 row updated normally
# 1654 row updated normally
# 1655 row updated normally
# 1656 row updated normally
# 1657 row updated normally
# 1658 row updated normally
# 1659 row updated normally
# 1660 row updated normally
# 1661 row updated normally
# 1662 row updated normally
# 1663 row updated normally
# 1664 row updated normally
# 1665 row updated normally
# 1666 row updated normally
# 1667 row updated normally
# 1668 row updated normally
# 1669 row updated normally
# 1670 row updated because lack of data
# 1671 row updated normally
# 1672 row updated normally
# 1673 row updated normally
# 1674 row updated normally
# 1675 row updated normally
# 1676 row updated normally
# 1677 row updated normally
# 1678 row updated normally
# 1679 row updated normally
# 1680 row updated normally
# 1681 row updated normally
# 1682 row updated normally
# 1683 row updated normally
# 1684 row updated normally
# 1685 row updated normally
# 1686 row updated normally
# 1687 row updated normally
# 1688 row updated normally
# 1689 row updated normally
# 1690 row updated normally
# 1691 row updated normally
# 1692 row updated normally
# 1693 row updated normally
# 1694 row updated normally
# 1695 row updated normally
# 1696 row updated normally
# 1697 row updated normally
# 1698 row updated normally
# 1699 row updated normally
# 1700 row updated normally
# 1701 row updated normally
# 1702 row updated normally
# 1703 row updated normally
# 1704 row updated normally
# 1705 row updated normally
# 1706 row updated normally
# 1707 row updated normally
# 1708 row updated normally
# 1709 row updated normally
# 1710 row updated normally
# 1711 row updated normally
# 1712 row updated normally
# 1713 row updated normally
# 1714 row updated normally
# 1715 row updated normally
# 1716 row updated normally
# 1717 row updated normally
# 1718 row updated normally
# 1719 row updated normally
# 1720 row updated normally
# 1721 row updated normally
# 1722 row updated normally
# 1723 row updated normally
# 1724 row updated normally
# 1725 row updated normally
# 1726 row updated normally
# 1727 row updated normally
# 1728 row updated normally
# 1729 row updated normally
# 1730 row updated normally
# 1731 row updated normally
# 1732 row updated normally
# 1733 row updated normally
# 1734 row updated normally
# 1735 row updated normally
# 1736 row updated normally
# 1737 row updated normally
# 1738 row updated normally
# 1739 row updated normally
# 1740 row updated normally
# 1741 row updated normally
# 1742 row updated normally
# 1743 row updated normally
# 1744 row updated normally
# 1745 row updated normally
# 1746 row updated normally
# 1747 row updated normally
# 1748 row updated normally
# 1749 row updated normally
# 1750 row updated normally
# 1751 row updated normally
# 1752 row updated normally
# 1753 row updated because lack of data
# 1754 row updated normally
# 1755 row updated normally
# 1756 row updated normally
# 1757 row updated because lack of data
# 1758 row updated normally
# 1759 row updated normally
# 1760 row updated normally
# 1761 row updated normally
# 1762 row updated normally
# 1763 row updated normally
# 1764 row updated normally
# 1765 row updated normally
# 1766 row updated normally
# 1767 row updated because lack of data
# 1768 row updated normally
# 1769 row updated normally
# 1770 row updated normally
# 1771 row updated normally
# 1772 row updated because lack of data
# 1773 row updated normally
# 1774 row updated normally
# 1775 row updated normally
# 1776 row updated normally
# 1777 row updated because lack of data
# 1778 row updated normally
# 1779 row updated normally
# 1780 row updated normally
# 1781 row updated normally
# 1782 row updated normally
# 1783 row updated because lack of data
# 1784 row updated because lack of data
# 1785 row updated because lack of data
# 1786 row updated because lack of data
# 1787 row updated because lack of data
# 1788 row updated because lack of data
# 1789 row updated because lack of data
# 1790 row updated because lack of data
# 1791 row updated because lack of data
# 1792 row updated because lack of data
# 1793 row updated because lack of data
# 1794 row updated because lack of data
# 1795 row updated because lack of data
# 1796 row updated because lack of data
# 1797 row updated because lack of data
# 1798 row updated because lack of data
# 1799 row updated because lack of data
# 1800 row updated because lack of data
# 1801 row updated because lack of data
# 1802 row updated because lack of data
# 1803 row updated because lack of data
# 1804 row updated because lack of data
# 1805 row updated because lack of data
# 1806 row updated because lack of data
# 1807 row updated because lack of data
# 1808 row updated because lack of data
# 1809 row updated because lack of data
# 1810 row updated because lack of data
# 1811 row updated because lack of data
# 1812 row updated because lack of data
# 1813 row updated because lack of data
# 1814 row updated because lack of data
# 1815 row updated because lack of data
# 1816 row updated because lack of data
# 1817 row updated because lack of data
# 1818 row updated because lack of data
# 1819 row updated because lack of data
# 1820 row updated because lack of data
# 1821 row updated because lack of data
# 1822 row updated because lack of data
# 1823 row updated because lack of data
# 1824 row updated because lack of data
# 1825 row updated because lack of data
# 1826 row updated because lack of data
# 1827 row updated because lack of data
# ...
# 10447 row updated because lack of data
# 10448 row updated because lack of data
# 10449 row updated because lack of data
# 10450 row updated because lack of data
# 10451 row updated because lack of data
# 10452 row updated because lack of data
# 10453 row updated because lack of data
# 10454 row updated because lack of data
# 10455 row updated because lack of data
# 10456 row updated because lack of data
# 10457 row updated because lack of data
# 10458 row updated because lack of data
# 10459 row updated because lack of data
# 10460 row updated because lack of data
# 10461 row updated because lack of data
# 10462 row updated because lack of data
# 10463 row updated because lack of data
# 10464 row updated because lack of data
# 10465 row updated because lack of data
# 10466 row updated because lack of data
# 10467 row updated because lack of data
# 10468 row updated because lack of data
# 10469 row updated because lack of data
# 10470 row updated because lack of data
# 10471 row updated because lack of data
# 10472 row updated because lack of data
# 10473 row updated because lack of data
# 10474 row updated because lack of data
# 10475 row updated because lack of data
# 10476 row updated because lack of data
# 10477 row updated because lack of data
# 10478 row updated because lack of data
# 10479 row updated because lack of data
# 10480 row updated because lack of data
# 10481 row updated because lack of data
# 10482 row updated because lack of data
# 10483 row updated because lack of data
# 10484 row updated because lack of data
# 10485 row updated because lack of data
# 10486 row updated because lack of data
# 10487 row updated because lack of data
# 10488 row updated because lack of data
# 10489 row updated because lack of data
# 10490 row updated because lack of data
# 10491 row updated because lack of data
# 10492 row updated because lack of data
# 10493 row updated because lack of data
# 10494 row updated because lack of data
# 10495 row updated because lack of data
# 10496 row updated because lack of data
# 10497 row updated because lack of data
# 10498 row updated because lack of data
# 10499 row updated because lack of data
# 10500 row updated because lack of data
# 10501 row updated because lack of data
# 10502 row updated because lack of data
# 10503 row updated because lack of data
# 10504 row updated because lack of data
# 10505 row updated because lack of data
# 10506 row updated because lack of data
# 10507 row updated because lack of data
# 10508 row updated because lack of data
# 10509 row updated because lack of data
# 10510 row updated because lack of data
# 10511 row updated because lack of data
# 10512 row updated normally
# 10513 row updated normally
# 10514 row updated normally
# 10515 row updated normally
# 10516 row updated normally
# 10517 row updated normally
# 10518 row updated normally
# 10519 row updated normally
# 10520 row updated normally
# 10521 row updated normally
# 10522 row updated normally
# 10523 row updated normally
# 10524 row updated normally
# 10525 row updated normally
# 10526 row updated normally
# 10527 row updated normally
# 10528 row updated normally
# 10529 row updated normally
# 10530 row updated normally
# 10531 row updated normally
# 10532 row updated normally
# 10533 row updated normally
# 10534 row updated normally
# 10535 row updated normally
# 10536 row updated normally
# 10537 row updated normally
# 10538 row updated normally
# 10539 row updated normally
# 10540 row updated normally
# 10541 row updated normally
# 10542 row updated normally
# 10543 row updated normally
# 10544 row updated normally
# 10545 row updated normally
# 10546 row updated normally
# 10547 row updated normally
# 10548 row updated normally
# 10549 row updated normally
# 10550 row updated normally
# 10551 row updated normally
# 10552 row updated normally
# 10553 row updated normally
# 10554 row updated normally
# 10555 row updated normally
# 10556 row updated normally
# 10557 row updated normally
# 10558 row updated normally
# 10559 row updated normally
# 10560 row updated normally
# 10561 row updated normally
# 10562 row updated normally
# 10563 row updated normally
# 10564 row updated normally
# 10565 row updated normally
# 10566 row updated normally
# 10567 row updated normally
# 10568 row updated normally
# 10569 row updated normally
# 10570 row updated normally
# 10571 row updated normally
# 10572 row updated normally
# 10573 row updated normally
# 10574 row updated normally
# 10575 row updated normally
# 10576 row updated normally
# 10577 row updated normally
# 10578 row updated normally
# 10579 row updated normally
# 10580 row updated normally
# 10581 row updated normally
# 10582 row updated normally
# 10583 row updated because lack of data
# 10584 row updated normally
# 10585 row updated because lack of data
# 10586 row updated normally
# 10587 row updated normally
# 10588 row updated because lack of data
# 10589 row updated normally
# 10590 row updated normally
# 10591 row updated because lack of data
# 10592 row updated normally
# 10593 row updated normally
# 10594 row updated normally
# 10595 row updated normally
# 10596 row updated normally
# 10597 row updated normally
# 10598 row updated normally
# 10599 row updated normally
# 10600 row updated normally
# 10601 row updated normally
# 10602 row updated normally
# 10603 row updated normally
# 10604 row updated normally
# 10605 row updated because lack of data
# 10606 row updated normally
# 10607 row updated normally
# 10608 row updated normally
# 10609 row updated normally
# 10610 row updated normally
# 10611 row updated normally
# 10612 row updated normally
# 10613 row updated normally
# 10614 row updated normally
# 10615 row updated normally
# 10616 row updated normally
# 10617 row updated normally
# 10618 row updated normally
# 10619 row updated normally
# 10620 row updated normally
# 10621 row updated normally
# 10622 row updated normally
# 10623 row updated normally
# 10624 row updated normally
# 10625 row updated normally
# 10626 row updated normally
# 10627 row updated normally
# 10628 row updated normally
# 10629 row updated normally
# 10630 row updated normally
# 10631 row updated normally
# 10632 row updated normally
# 10633 row updated normally
# 10634 row updated normally
# 10635 row updated normally
# 10636 row updated normally
# 10637 row updated normally
# 10638 row updated normally
# 10639 row updated normally
# 10640 row updated normally
# 10641 row updated normally
# 10642 row updated normally
# 10643 row updated normally
# 10644 row updated normally
# 10645 row updated normally
# 10646 row updated normally
# 10647 row updated normally
# 10648 row updated normally
# 10649 row updated normally
# 10650 row updated normally
# 10651 row updated normally
# 10652 row updated normally
# 10653 row updated normally
# 10654 row updated normally
# 10655 row updated normally
# 10656 row updated normally
# 10657 row updated normally
# 10658 row updated normally
# 10659 row updated normally
# 10660 row updated normally
# 10661 row updated because lack of data
# 10662 row updated because lack of data
# 10663 row updated because lack of data
# 10664 row updated normally
# 10665 row updated normally
# 10666 row updated normally
# 10667 row updated because lack of data
# 10668 row updated normally
# 10669 row updated normally
# 10670 row updated normally
# 10671 row updated normally
# 10672 row updated normally
# 10673 row updated because lack of data
# 10674 row updated because lack of data
# 10675 row updated because lack of data
# 10676 row updated normally
# 10677 row updated normally
# 10678 row updated normally
# 10679 row updated normally
# 10680 row updated normally
# 10681 row updated normally
# 10682 row updated normally
# 10683 row updated normally
# 10684 row updated normally
# 10685 row updated normally
# 10686 row updated normally
# 10687 row updated normally
# 10688 row updated normally
# 10689 row updated normally
# 10690 row updated normally
# 10691 row updated because lack of data
# 10692 row updated normally
# 10693 row updated normally
# 10694 row updated normally
# 10695 row updated normally
# 10696 row updated normally
# 10697 row updated normally
# 10698 row updated normally
# 10699 row updated normally
# 10700 row updated normally
# 10701 row updated normally
# 10702 row updated normally
# 10703 row updated normally
# 10704 row updated normally
# 10705 row updated normally
# 10706 row updated normally
# 10707 row updated normally
# 10708 row updated normally
# 10709 row updated normally
# 10710 row updated normally
# 10711 row updated normally
# 10712 row updated normally
# 10713 row updated normally
# 10714 row updated normally
# 10715 row updated normally
# 10716 row updated normally
# 10717 row updated normally
# 10718 row updated normally
# 10719 row updated normally
# 10720 row updated normally
# 10721 row updated normally
# 10722 row updated normally
# 10723 row updated normally
# 10724 row updated normally
# 10725 row updated normally
# 10726 row updated normally
# 10727 row updated normally
# 10728 row updated normally
# 10729 row updated because lack of data
# 10730 row updated because lack of data
# 10731 row updated normally
# 10732 row updated normally
# 10733 row updated normally
# 10734 row updated normally
# 10735 row updated normally
# 10736 row updated normally
# 10737 row updated normally
# 10738 row updated normally
# 10739 row updated normally
# 10740 row updated because lack of data
# 10741 row updated because lack of data
# 10742 row updated normally
# 10743 row updated because lack of data
# 10744 row updated normally
# 10745 row updated because lack of data
# 10746 row updated normally
# 10747 row updated normally
# 10748 row updated normally
# 10749 row updated normally
# 10750 row updated normally
# 10751 row updated normally
# 10752 row updated normally
# 10753 row updated normally
# 10754 row updated normally
# 10755 row updated normally
# 10756 row updated normally
# 10757 row updated normally
# 10758 row updated normally
# 10759 row updated normally
# 10760 row updated normally
# 10761 row updated normally
# 10762 row updated normally
# 10763 row updated normally
# 10764 row updated normally
# 10765 row updated normally
# 10766 row updated normally
# 10767 row updated normally
# 10768 row updated normally
# 10769 row updated normally
# 10770 row updated normally
# 10771 row updated normally
# 10772 row updated normally
# 10773 row updated normally
# 10774 row updated normally
# 10775 row updated because lack of data
# 10776 row updated because lack of data
# 10777 row updated because lack of data
# 10778 row updated normally
# 10779 row updated normally
# 10780 row updated normally
# 10781 row updated normally
# 10782 row updated normally
# 10783 row updated normally
# 10784 row updated normally
# 10785 row updated normally
# 10786 row updated normally
# 10787 row updated normally
# 10788 row updated normally
# 10789 row updated normally
# 10790 row updated normally
# 10791 row updated normally
# 10792 row updated normally
# 10793 row updated normally
# 10794 row updated normally
# 10795 row updated normally
# 10796 row updated normally
# 10797 row updated normally
# 10798 row updated normally
# 10799 row updated normally
# 10800 row updated normally
# 10801 row updated normally
# 10802 row updated normally
# 10803 row updated normally
# 10804 row updated normally
# 10805 row updated normally
# 10806 row updated normally
# 10807 row updated normally
# 10808 row updated normally
# 10809 row updated normally
# 10810 row updated normally
# 10811 row updated normally
# 10812 row updated normally
# 10813 row updated because lack of data
# 10814 row updated because lack of data
# 10815 row updated normally
# 10816 row updated because lack of data
# 10817 row updated normally
# 10818 row updated normally
# 10819 row updated normally
# 10820 row updated normally
# 10821 row updated normally
# 10822 row updated normally
# 10823 row updated because lack of data
# 10824 row updated normally
# 10825 row updated normally
# 10826 row updated normally
# 10827 row updated because lack of data
# 10828 row updated normally
# 10829 row updated normally
# 10830 row updated normally
# 10831 row updated normally
# 10832 row updated normally
# 10833 row updated normally
# 10834 row updated normally
# 10835 row updated normally
# 10836 row updated because lack of data
# 10837 row updated normally
# 10838 row updated normally
# 10839 row updated normally
# 10840 row updated normally
# 10841 row updated normally
# 10842 row updated because lack of data
# 10843 row updated normally
# 10844 row updated normally
# 10845 row updated normally
# 10846 row updated normally
# 10847 row updated normally
# 10848 row updated normally
# 10849 row updated normally
# 10850 row updated normally
# 10851 row updated normally
# 10852 row updated normally
# 10853 row updated normally
# 10854 row updated normally
# 10855 row updated normally
# 10856 row updated normally
# 10857 row updated normally
# 10858 row updated normally
# 10859 row updated normally
# 10860 row updated because lack of data
# 10861 row updated normally
# 10862 row updated normally
# 10863 row updated normally
# 10864 row updated because lack of data
# 10865 row updated normally
# 10866 row updated because lack of data
# 10867 row updated normally
# 10868 row updated normally
# 10869 row updated normally
# 10870 row updated normally
# 10871 row updated normally
# 10872 row updated normally
# 10873 row updated normally
# 10874 row updated normally
# 10875 row updated because lack of data
# 10876 row updated normally
# 10877 row updated normally
# 10878 row updated normally
# 10879 row updated normally
# 10880 row updated normally
# 10881 row updated normally
# 10882 row updated because lack of data
# 10883 row updated normally
# 10884 row updated normally
# 10885 row updated normally
# 10886 row updated normally
# 10887 row updated because lack of data
# 10888 row updated normally
# 10889 row updated normally
# 10890 row updated normally
# 10891 row updated because lack of data
# 10892 row updated normally
# 10893 row updated normally
# 10894 row updated normally
# 10895 row updated normally
# 10896 row updated normally
# 10897 row updated normally
# 10898 row updated normally
# 10899 row updated normally
# 10900 row updated because lack of data
# 10901 row updated normally
# 10902 row updated normally
# 10903 row updated normally
# 10904 row updated because lack of data
# 10905 row updated normally
# 10906 row updated normally
# 10907 row updated because lack of data
# 10908 row updated normally
# 10909 row updated normally
# 10910 row updated normally
# 10911 row updated normally
# 10912 row updated normally
# 10913 row updated normally
# 10914 row updated normally
# 10915 row updated normally
# 10916 row updated normally
# 10917 row updated normally
# 10918 row updated normally
# 10919 row updated normally
# 10920 row updated normally
# 10921 row updated normally
# 10922 row updated normally
# 10923 row updated normally
# 10924 row updated normally
# 10925 row updated normally
# 10926 row updated normally
# 10927 row updated normally
# 10928 row updated normally
# 10929 row updated normally
# 10930 row updated normally
# 10931 row updated normally
# 10932 row updated normally
# 10933 row updated normally
# 10934 row updated normally
# 10935 row updated normally
# 10936 row updated normally
# 10937 row updated normally
# 10938 row updated normally
# 10939 row updated normally
# 10940 row updated normally
# 10941 row updated normally
# 10942 row updated normally
# 10943 row updated normally
# 10944 row updated normally
# 10945 row updated normally
# 10946 row updated normally
# 10947 row updated normally
# 10948 row updated normally
# 10949 row updated normally
# 10950 row updated normally
# 10951 row updated normally
# 10952 row updated normally
# 10953 row updated normally
# 10954 row updated normally
# 10955 row updated normally
# 10956 row updated normally
# 10957 row updated normally
# 10958 row updated normally
# 10959 row updated normally
# 10960 row updated normally
# 10961 row updated normally
# 10962 row updated normally
# 10963 row updated normally
# 10964 row updated normally
# 10965 row updated normally
# 10966 row updated normally
# 10967 row updated normally
# 10968 row updated normally
# 10969 row updated normally
# 10970 row updated normally
# 10971 row updated normally
# 10972 row updated normally
# 10973 row updated normally
# 10974 row updated normally
# 10975 row updated normally
# 10976 row updated normally
# 10977 row updated normally
# 10978 row updated normally
# 10979 row updated normally
# 10980 row updated normally
# 10981 row updated normally
# 10982 row updated normally
# 10983 row updated because lack of data
# 10984 row updated because lack of data
# 10985 row updated because lack of data
# 10986 row updated because lack of data
# 10987 row updated because lack of data
# 10988 row updated because lack of data
# 10989 row updated because lack of data

# %%
frequent_location_with_past = pd.read_csv("location_with_last_week_info.csv")

# %%
frequent_location_with_past = frequent_location_with_past.drop(['Unnamed: 0'], axis = 1)
frequent_location_with_past
# Out:
#                               place_name  \
# 0              Oryx Prive Investment LLC
# 1                          Hayley Denton
# 2                                  SHAEF
# 3       Richmond Trees and Landscape Ltd
# 4         PJA Marketing & Communications
# ...                                  ...
# 11326                     Mabledon Court
# 11327  Mary Ward House Conference Centre
# 11328       Kimpton Fitzroy London Hotel
# 11329  Mary Ward House Conference Centre
# 11330       Coffey, A Tetra Tech Company
#
#                                              place_types  presence_likelihood  \
# 0               FINANCE,POINT_OF_INTEREST,ESTABLISHMENT,             0.356970
# 1                       POINT_OF_INTEREST,ESTABLISHMENT,             0.170476
# 2                  PARK,POINT_OF_INTEREST,ESTABLISHMENT,             0.416301
# 3      GENERAL_CONTRACTOR,POINT_OF_INTEREST,ESTABLISH...             0.229612
# 4                       POINT_OF_INTEREST,ESTABLISHMENT,             0.109734
# ...                                                  ...                  ...
# 11326           LODGING,POINT_OF_INTEREST,ESTABLISHMENT,             0.252579
# 11327           LODGING,POINT_OF_INTEREST,ESTABLISHMENT,             0.156345
# 11328           LODGING,POINT_OF_INTEREST,ESTABLISHMENT,             0.450344
# 11329           LODGING,POINT_OF_INTEREST,ESTABLISHMENT,             0.154135
# 11330                   POINT_OF_INTEREST,ESTABLISHMENT,             0.453755
#
#                   datetime              type_1             type_2  \
# 0      2010-07-21 07:00:00             FINANCE  POINT_OF_INTEREST
# 1      2010-07-21 01:00:00   POINT_OF_INTEREST      ESTABLISHMENT
# 2      2010-07-21 00:40:00                PARK  POINT_OF_INTEREST
# 3      2010-07-21 00:20:00  GENERAL_CONTRACTOR  POINT_OF_INTEREST
# 4      2010-07-21 00:00:00   POINT_OF_INTEREST      ESTABLISHMENT
# ...                    ...                 ...                ...
# 11326  2010-01-01 07:20:00             LODGING  POINT_OF_INTEREST
# 11327  2010-01-01 07:00:00             LODGING  POINT_OF_INTEREST
# 11328  2010-01-01 06:40:00             LODGING  POINT_OF_INTEREST
# 11329  2010-01-01 06:20:00             LODGING  POINT_OF_INTEREST
# 11330  2010-01-01 06:00:00   POINT_OF_INTEREST      ESTABLISHMENT
#
#               type_3 type_4 type_5 type_6  ... type_12        type_4_hours  \
# 0      ESTABLISHMENT      0      0      0  ...       0             LODGING
# 1                  0      0      0      0  ...       0             LODGING
# 2      ESTABLISHMENT      0      0      0  ...       0             LODGING
# 3      ESTABLISHMENT      0      0      0  ...       0             LODGING
# 4                  0      0      0      0  ...       0             LODGING
# ...              ...    ...    ...    ...  ...     ...                 ...
# 11326  ESTABLISHMENT      0      0      0  ...       0  GENERAL_CONTRACTOR
# 11327  ESTABLISHMENT      0      0      0  ...       0   ELECTRONICS_STORE
# 11328  ESTABLISHMENT      0      0      0  ...       0   ELECTRONICS_STORE
# 11329  ESTABLISHMENT      0      0      0  ...       0   ELECTRONICS_STORE
# 11330              0      0      0      0  ...       0               STORE
#
#                type_1_day         type_7_days weekday mins hours  \
# 0                  MUSEUM               STORE       2    0     7
# 1                  MUSEUM               STORE       2    0     1
# 2                  MUSEUM               STORE       2   40     0
# 3                  MUSEUM               STORE       2   20     0
# 4                  MUSEUM               STORE       2    0     0
# ...                   ...                 ...     ...  ...   ...
# 11326  GENERAL_CONTRACTOR  GENERAL_CONTRACTOR       4   20     7
# 11327               STORE               STORE       4    0     7
# 11328               STORE               STORE       4   40     6
# 11329               STORE               STORE       4   20     6
# 11330               STORE               STORE       4    0     6
#
#        week_bfr_4_hours week_bfr_1_day  week_bfr_7_days
# 0         MEAL_TAKEAWAY     CAR_REPAIR                0
# 1         MEAL_TAKEAWAY     CAR_REPAIR                0
# 2                HEALTH     CAR_REPAIR                0
# 3         MEAL_TAKEAWAY     CAR_REPAIR                0
# 4      SECONDARY_SCHOOL     CAR_REPAIR                0
# ...                 ...            ...              ...
# 11326                 0              0                0
# 11327                 0              0                0
# 11328                 0              0                0
# 11329                 0              0                0
# 11330                 0              0                0
#
# [11331 rows x 25 columns]

# %%
# Add random advertisements to locations
for

# %%
frequent_location_with_past.type_4_hours.unique()
# Out:
# array(['LODGING', 'SUPERMARKET', 'PARK', 'BAR', 'CAFE', 'BICYCLE_STORE',
#        'SCHOOL', 'TOURIST_ATTRACTION', 'HARDWARE_STORE', 'STORE',
#        'TRAVEL_AGENCY', 'CHURCH', 'PARKING', 'MUSEUM',
#        'ELECTRONICS_STORE', 'AMUSEMENT_PARK', 'CONVENIENCE_STORE',
#        'POST_OFFICE', 'ROOFING_CONTRACTOR', 'CAR_RENTAL', 'RESTAURANT',
#        'JEWELRY_STORE', 'FURNITURE_STORE', 'PRIMARY_SCHOOL',
#        'REAL_ESTATE_AGENCY', 'PET_STORE', 'DOCTOR', 'FINANCE', 'PAINTER',
#        'HEALTH', 'ART_GALLERY', 'FLORIST', 'CAR_REPAIR', 'LIQUOR_STORE',
#        'CLOTHING_STORE', 'GROCERY_OR_SUPERMARKET', 'MEAL_TAKEAWAY',
#        'TRAIN_STATION', 'STADIUM', 'STORAGE', 'UNIVERSITY', 'MOSQUE',
#        'GENERAL_CONTRACTOR', 'PHARMACY', 'FOOD', 'LIBRARY',
#        'SUBWAY_STATION', 'FIRE_STATION', 'CAR_DEALER', 'SECONDARY_SCHOOL',
#        'LAUNDRY', 'HOSPITAL', 'INSURANCE_AGENCY', 'PLUMBER', 'BANK',
#        'LAWYER', 'PHYSIOTHERAPIST', 'EMBASSY', 'FUNERAL_HOME',
#        'HOME_GOODS_STORE', 'BOOK_STORE', 'ACCOUNTING', 'ELECTRICIAN',
#        'SYNAGOGUE', 'TRANSIT_STATION', 'CEMETERY', 'MOVING_COMPANY',
#        'BAKERY', 'VETERINARY_CARE', 'GYM', 'LOCKSMITH', 'LOCALITY', 'ATM',
#        'GAS_STATION', 'POLICE', 'NIGHT_CLUB', 'PLACE_OF_WORSHIP',
#        'POLITICAL', 'RV_PARK', 'LOCAL_GOVERNMENT_OFFICE', 'BUS_STATION',
#        'MEAL_DELIVERY', 'CAR_WASH', 'DRUGSTORE', 'HAIR_CARE',
#        'COURTHOUSE', 'DENTIST', 'SHOE_STORE', 'PREMISE',
#        'DEPARTMENT_STORE', 'SPA', 'POSTAL_CODE', 'CASINO',
#        'SHOPPING_MALL', 'POSTAL_CODE_PREFIX', 'NATURAL_FEATURE',
#        'COUNTRY', 'COLLOQUIAL_AREA', 'CONTINENT', 'BEAUTY_SALON',
#        'MOVIE_THEATER', 'TAXI_STAND', 'ZOO', 'HINDU_TEMPLE', 'AIRPORT'],
#       dtype=object)

# %%
frequent_location_with_past.type_1.unique().__len__()
# Out:
# 106

# %%
LODGING 
SUPERMARKET
PARK
BAR
CAFE
BICYCLE_STORE
SCHOOL
TOURIST_ATTRACTION
HARDWARE_STORE
STORE
TRAVEL_AGENCY
CHURCH
PARKING
MUSEUM
ELECTRONICS_STORE
AMUSEMENT_PARK
CONVENIENCE_STORE
POST_OFFICE
ROOFING_CONTRACTOR
CAR_RENTAL
RESTAURANT
JEWELRY_STORE
FURNITURE_STORE
PRIMARY_SCHOOL
REAL_ESTATE_AGENCY
PET_STORE
DOCTOR
FINANCE
PAINTER
HEALTH
ART_GALLERY
FLORIST
CAR_REPAIR
LIQUOR_STORE
CLOTHING_STORE
GROCERY_OR_SUPERMARKET
MEAL_TAKEAWAY
TRAIN_STATION
STADIUM
STORAGE
UNIVERSITY
MOSQUE
GENERAL_CONTRACTOR
PHARMACY
FOOD
LIBRARY
SUBWAY_STATION
FIRE_STATION
CAR_DEALER
SECONDARY_SCHOOL
LAUNDRY
HOSPITAL
INSURANCE_AGENCY
PLUMBER
BANK
LAWYER
PHYSIOTHERAPIST
EMBASSY
FUNERAL_HOME
HOME_GOODS_STORE
BOOK_STORE
ACCOUNTING
ELECTRICIAN
SYNAGOGUE
TRANSIT_STATION
CEMETERY
MOVING_COMPANY
BAKERY
VETERINARY_CARE
GYM
LOCKSMITH
LOCALITY
ATM
GAS_STATION
POLICE
NIGHT_CLUB
PLACE_OF_WORSHIP
POLITICAL
RV_PARK
LOCAL_GOVERNMENT_OFFICE
BUS_STATION
MEAL_DELIVERY
CAR_WASH
DRUGSTORE
HAIR_CARE
COURTHOUSE
DENTIST
SHOE_STORE
PREMISE
DEPARTMENT_STORE
SPA
POSTAL_CODE
CASINO
SHOPPING_MALL
POSTAL_CODE_PREFIX
NATURAL_FEATURE
COUNTRY
COLLOQUIAL_AREA
CONTINENT
BEAUTY_SALON
MOVIE_THEATER
TAXI_STAND
ZOO
HINDU_TEMPLE
AIRPORT
# Out:
# ('MOVIE_THEATER', 'TAXI_STAND', 'ZOO', 'HINDU_TEMPLE', 'AIRPORT')
